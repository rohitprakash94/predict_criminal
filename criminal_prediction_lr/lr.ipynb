# %%
import pandas as pd

# %%
dataset = pd.read_csv("criminal_train.csv")

# %%
dataset.head()
dataset.loc[:,"PERID":"PERID"]
# Out:
#           PERID
# 0      25095143
# 1      13005143
# 2      67415143
# 3      70925143
# 4      75235143
# 5      47745143
# 6      33145143
# 7      63765143
# 8      57796143
# 9      66416143
# 10     51916143
# 11     40016143
# 12     99116143
# 13     85326143
# 14     63336143
# 15     64946143
# 16     73856143
# 17     82956143
# 18     65276143
# 19     58307143
# 20     67407143
# 21     83427143
# 22     68447143
# 23     65177143
# 24     77787143
# 25     96887143
# 26     46218143
# 27     15938143
# 28     15268143
# 29     79868143
# ...         ...
# 45688  14130679
# 45689  21950679
# 45690  65360679
# 45691  29960679
# 45692  22470679
# 45693  67970679
# 45694  95501679
# 45695  30001679
# 45696  64411679
# 45697  34221679
# 45698  11331679
# 45699  19671679
# 45700  37681679
# 45701  49002679
# 45702  67632679
# 45703  15352679
# 45704  71752679
# 45705  86062679
# 45706  17772679
# 45707  29382679
# 45708  99193679
# 45709  23313679
# 45710  90423679
# 45711  88143679
# 45712  75253679
# 45713  29663679
# 45714  43073679
# 45715  52173679
# 45716  29283679
# 45717  87483679
#
# [45718 rows x 1 columns]

# %%
dataset.shape
# Out:
# (45718, 72)

# %%
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(dataset, test_size=0.2)

# %%
train.shape
# Out:
# (36574, 72)

# %%
test.shape
# Out:
# (9144, 72)

# %%
dataset.groupby('Criminal').size()
# Out:
# Criminal
# 0    42543
# 1     3175
# dtype: int64

# %%
train.groupby('Criminal').size()
# Out:
# Criminal
# 0    33998
# 1     2576
# dtype: int64

# %%
test.groupby('Criminal').size()
# Out:
# Criminal
# 0    8545
# 1     599
# dtype: int64

# %%
x_train = train.loc[:,"IFATHER":"VEREP"]

# %%
x_train.head()
# Out:
#        IFATHER  NRCH17_2  IRHHSIZ2  IIHHSIZ2  IRKI17_2  IIKI17_2  IRHH65_2  \
# 44890        4         1         5         1         2         1         1
# 24699        4         0         2         1         1         1         1
# 20729        4         0         2         1         1         1         3
# 38032        4         0         3         1         1         1         2
# 37904        4         0         1         1         1         1         1
#
#        IIHH65_2  PRXRETRY  PRXYDATA  ...    POVERTY3  TOOLONG  TROUBUND  \
# 44890         1        99        99  ...           1        2         2
# 24699         1        99        99  ...           1        2         2
# 20729         1        99        99  ...           3        1         2
# 38032         1        99        99  ...           3        2         1
# 37904         1        99        99  ...           3        2         2
#
#        PDEN10  COUTYP2  MAIIN102  AIIND102     ANALWT_C  VESTR  VEREP
# 44890       1        1         2         2   245.678072  40027      1
# 24699       2        2         2         2    50.741878  40034      1
# 20729       2        3         2         2  9641.624635  40012      2
# 38032       2        2         2         2  1126.953266  40028      2
# 37904       2        2         2         2  2103.425970  40039      1
#
# [5 rows x 70 columns]

# %%
y_train = train.loc[:,"Criminal":]

# %%
y_train.head()
# Out:
#        Criminal
# 44890         0
# 24699         0
# 20729         0
# 38032         0
# 37904         0

# %%
x_test = test.loc[:,"IFATHER":"VEREP"]

# %%
x_test.head()
# Out:
#        IFATHER  NRCH17_2  IRHHSIZ2  IIHHSIZ2  IRKI17_2  IIKI17_2  IRHH65_2  \
# 11848        4         0         1         1         1         1         1
# 16177        4         1         5         1         2         1         1
# 13600        4         2         4         1         3         1         1
# 12604        4         0         2         1         1         1         1
# 10620        4         0         2         1         1         1         1
#
#        IIHH65_2  PRXRETRY  PRXYDATA  ...    POVERTY3  TOOLONG  TROUBUND  \
# 11848         1        99        99  ...           3        2         1
# 16177         1        99        99  ...           2        2         2
# 13600         1        99        99  ...           3        2         2
# 12604         1        99        99  ...           3        2         2
# 10620         1        99        99  ...           3        2         2
#
#        PDEN10  COUTYP2  MAIIN102  AIIND102      ANALWT_C  VESTR  VEREP
# 11848       1        1         2         2    996.382032  40007      2
# 16177       2        3         2         2  23871.183310  40047      1
# 13600       1        1         2         2   6869.123610  40029      1
# 12604       2        2         2         2    408.546145  40030      1
# 10620       2        2         2         2   5607.583610  40023      2
#
# [5 rows x 70 columns]

# %%
y_test = test.loc[:,"Criminal":]

# %%
y_test.head()
# Out:
#        Criminal
# 13647         0
# 38300         0
# 39580         1
# 6605          0
# 43996         0

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train,y_train.values.ravel())
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
pred = lr.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy = accuracy_score(y_test, pred)

# %%
print(accuracy)
# Out:
# 0.935258092738

# %%
print(pred)
# Out:
# [0 0 0 ..., 0 0 0]
