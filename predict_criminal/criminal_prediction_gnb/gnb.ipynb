# %%
import pandas as pd

# %%
dataset = pd.read_csv("criminal_train.csv")

# %%
dataset.head()
dataset.loc[:,"PERID":"PERID"]
# Out:
#           PERID
# 0      25095143
# 1      13005143
# 2      67415143
# 3      70925143
# 4      75235143
# 5      47745143
# 6      33145143
# 7      63765143
# 8      57796143
# 9      66416143
# 10     51916143
# 11     40016143
# 12     99116143
# 13     85326143
# 14     63336143
# 15     64946143
# 16     73856143
# 17     82956143
# 18     65276143
# 19     58307143
# 20     67407143
# 21     83427143
# 22     68447143
# 23     65177143
# 24     77787143
# 25     96887143
# 26     46218143
# 27     15938143
# 28     15268143
# 29     79868143
# ...         ...
# 45688  14130679
# 45689  21950679
# 45690  65360679
# 45691  29960679
# 45692  22470679
# 45693  67970679
# 45694  95501679
# 45695  30001679
# 45696  64411679
# 45697  34221679
# 45698  11331679
# 45699  19671679
# 45700  37681679
# 45701  49002679
# 45702  67632679
# 45703  15352679
# 45704  71752679
# 45705  86062679
# 45706  17772679
# 45707  29382679
# 45708  99193679
# 45709  23313679
# 45710  90423679
# 45711  88143679
# 45712  75253679
# 45713  29663679
# 45714  43073679
# 45715  52173679
# 45716  29283679
# 45717  87483679
#
# [45718 rows x 1 columns]

# %%
dataset.shape
# Out:
# (45718, 72)

# %%
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(dataset, test_size=0.2)

# %%
train.shape
# Out:
# (36574, 72)

# %%
test.shape
# Out:
# (9144, 72)

# %%
dataset.groupby('Criminal').size()
# Out:
# Criminal
# 0    42543
# 1     3175
# dtype: int64

# %%
train.groupby('Criminal').size()
# Out:
# Criminal
# 0    34073
# 1     2501
# dtype: int64

# %%
test.groupby('Criminal').size()
# Out:
# Criminal
# 0    8470
# 1     674
# dtype: int64

# %%
x_train = train.loc[:,"IFATHER":"VEREP"]

# %%
x_train.head()
# Out:
#        IFATHER  NRCH17_2  IRHHSIZ2  IIHHSIZ2  IRKI17_2  IIKI17_2  IRHH65_2  \
# 20645        4         0         2         1         1         1         2
# 44251        1         0         5         1         3         1         1
# 22067        4         0         3         1         1         1         1
# 17446        4         0         3         1         1         1         1
# 28625        4         0         2         1         1         1         2
#
#        IIHH65_2  PRXRETRY  PRXYDATA  ...    POVERTY3  TOOLONG  TROUBUND  \
# 20645         1        99        99  ...           3        2         1
# 44251         1        99         1  ...           1        2         2
# 22067         1        99        99  ...           2        2         2
# 17446         1        99        99  ...           3        2         2
# 28625         1        99        99  ...           3        2         2
#
#        PDEN10  COUTYP2  MAIIN102  AIIND102     ANALWT_C  VESTR  VEREP
# 20645       2        3         2         2  5640.733584  40034      1
# 44251       2        3         2         2  2587.434703  40043      2
# 22067       2        2         2         2  3707.777702  40016      1
# 17446       2        1         2         2  7784.677975  40011      2
# 28625       2        1         2         2  5189.710245  40006      2
#
# [5 rows x 70 columns]

# %%
y_train = train.loc[:,"Criminal":]

# %%
y_train.head()
# Out:
#        Criminal
# 20645         0
# 44251         1
# 22067         0
# 17446         0
# 28625         0

# %%
x_test = test.loc[:,"IFATHER":"VEREP"]

# %%
x_test.head()
# Out:
#        IFATHER  NRCH17_2  IRHHSIZ2  IIHHSIZ2  IRKI17_2  IIKI17_2  IRHH65_2  \
# 29851        4         0         2         1         1         1         2
# 24364        4         0         2         1         1         1         1
# 33415        1         0         5         1         3         1         1
# 33064        4         2         4         1         3         1         1
# 37332        1         0         3         1         2         1         1
#
#        IIHH65_2  PRXRETRY  PRXYDATA  ...    POVERTY3  TOOLONG  TROUBUND  \
# 29851         1        99        99  ...           3        2         2
# 24364         1        99        99  ...           1        2         2
# 33415         1        99         1  ...           1        2         2
# 33064         1        99        99  ...           3        2         2
# 37332         1        99         1  ...           3        2         2
#
#        PDEN10  COUTYP2  MAIIN102  AIIND102      ANALWT_C  VESTR  VEREP
# 29851       1        1         2         2   1612.945966  40019      2
# 24364       2        2         2         2   4036.710115  40049      2
# 33415       1        1         2         2   1876.197849  40025      1
# 33064       1        1         2         2  19099.473610  40012      1
# 37332       2        3         2         2   2141.997118  40006      1
#
# [5 rows x 70 columns]

# %%
y_test = test.loc[:,"Criminal":]

# %%
y_test.head()
# Out:
#        Criminal
# 29851         0
# 24364         1
# 33415         0
# 33064         0
# 37332         0

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnb =GaussianNB()

# %%
gnb.fit(x_train,y_train.values.ravel())
# Out:
# GaussianNB(priors=None)

# %%
pred = gnb.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy = accuracy_score(y_test, pred)

# %%
print(accuracy)
# Out:
# 0.214566929134

# %%
print(pred)
# Out:
# [1 0 0 ..., 0 1 1]
