# %%
import pandas as pd

# %%
dataset = pd.read_csv("criminal_train.csv")

# %%
dataset.head()
dataset.loc[:,"PERID":"PERID"]
# Out:
#           PERID
# 0      25095143
# 1      13005143
# 2      67415143
# 3      70925143
# 4      75235143
# 5      47745143
# 6      33145143
# 7      63765143
# 8      57796143
# 9      66416143
# 10     51916143
# 11     40016143
# 12     99116143
# 13     85326143
# 14     63336143
# 15     64946143
# 16     73856143
# 17     82956143
# 18     65276143
# 19     58307143
# 20     67407143
# 21     83427143
# 22     68447143
# 23     65177143
# 24     77787143
# 25     96887143
# 26     46218143
# 27     15938143
# 28     15268143
# 29     79868143
# ...         ...
# 45688  14130679
# 45689  21950679
# 45690  65360679
# 45691  29960679
# 45692  22470679
# 45693  67970679
# 45694  95501679
# 45695  30001679
# 45696  64411679
# 45697  34221679
# 45698  11331679
# 45699  19671679
# 45700  37681679
# 45701  49002679
# 45702  67632679
# 45703  15352679
# 45704  71752679
# 45705  86062679
# 45706  17772679
# 45707  29382679
# 45708  99193679
# 45709  23313679
# 45710  90423679
# 45711  88143679
# 45712  75253679
# 45713  29663679
# 45714  43073679
# 45715  52173679
# 45716  29283679
# 45717  87483679
#
# [45718 rows x 1 columns]

# %%
dataset.shape
# Out:
# (45718, 72)

# %%
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(dataset, test_size=0.2)

# %%
train.shape
# Out:
# (36574, 72)

# %%
test.shape
# Out:
# (9144, 72)

# %%
dataset.groupby('Criminal').size()
# Out:
# Criminal
# 0    42543
# 1     3175
# dtype: int64

# %%
train.groupby('Criminal').size()
# Out:
# Criminal
# 0    33991
# 1     2583
# dtype: int64

# %%
test.groupby('Criminal').size()
# Out:
# Criminal
# 0    8552
# 1     592
# dtype: int64

# %%
x_train = train.loc[:,"IFATHER":"VEREP"]

# %%
x_train.head()
# Out:
#        IFATHER  NRCH17_2  IRHHSIZ2  IIHHSIZ2  IRKI17_2  IIKI17_2  IRHH65_2  \
# 18498        1         0         4         1         3         1         1
# 22937        4         0         2         1         1         1         1
# 27877        1         0         3         1         2         1         1
# 42944        4         0         4         1         2         1         1
# 14616        1         0         4         1         2         1         1
#
#        IIHH65_2  PRXRETRY  PRXYDATA  ...    POVERTY3  TOOLONG  TROUBUND  \
# 18498         1        99         1  ...           3        2         2
# 22937         1        99        99  ...           3        2         2
# 27877         1        99         1  ...           1        2         2
# 42944         1        99        99  ...           2        2         2
# 14616         1        99         1  ...           3        2         2
#
#        PDEN10  COUTYP2  MAIIN102  AIIND102     ANALWT_C  VESTR  VEREP
# 18498       1        1         2         2  1884.982564  40043      2
# 22937       2        2         2         2  1623.243754  40003      1
# 27877       1        1         2         2  1390.238323  40029      2
# 42944       2        2         2         2   306.255452  40017      1
# 14616       1        1         2         2  2175.547023  40029      1
#
# [5 rows x 70 columns]

# %%
y_train = train.loc[:,"Criminal":]

# %%
y_train.head()
# Out:
#        Criminal
# 18498         0
# 22937         1
# 27877         0
# 42944         0
# 14616         0

# %%
x_test = test.loc[:,"IFATHER":"VEREP"]

# %%
x_test.head()
# Out:
#        IFATHER  NRCH17_2  IRHHSIZ2  IIHHSIZ2  IRKI17_2  IIKI17_2  IRHH65_2  \
# 9677         4         2         3         1         3         1         1
# 5389         4         3         4         1         4         1         1
# 43115        1         0         4         1         3         1         1
# 2626         2         0         6         1         4         1         1
# 17127        4         0         4         1         1         1         1
#
#        IIHH65_2  PRXRETRY  PRXYDATA  ...    POVERTY3  TOOLONG  TROUBUND  \
# 9677          1        99        99  ...           2        2         2
# 5389          1        99        99  ...           1        2         2
# 43115         1        99         1  ...           3        2         2
# 2626          1        99         1  ...           1        2         2
# 17127         1        99        99  ...           3        2         2
#
#        PDEN10  COUTYP2  MAIIN102  AIIND102     ANALWT_C  VESTR  VEREP
# 9677        2        2         2         2  4518.505580  40022      1
# 5389        1        1         2         2   762.171157  40015      2
# 43115       2        1         2         2  2353.295535  40014      2
# 2626        2        1         2         2   709.944291  40002      1
# 17127       1        1         2         2  9979.303958  40019      1
#
# [5 rows x 70 columns]

# %%
y_test = test.loc[:,"Criminal":]

# %%
y_test.head()
# Out:
#        Criminal
# 9677          0
# 5389          0
# 43115         0
# 2626          0
# 17127         0

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnb =GaussianNB()

# %%
gnb.fit(x_train,y_train.values.ravel())
# Out:
# GaussianNB(priors=None)

# %%
pred = gnb.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy = accuracy_score(y_test, pred)

# %%
print(accuracy)
# Out:
# 0.935586176728

# %%
print(pred)
# Out:
# [1 0 0 ..., 0 0 1]
