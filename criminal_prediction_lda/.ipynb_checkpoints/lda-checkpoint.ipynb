# %%
import pandas as pd

# %%
dataset = pd.read_csv("criminal_train.csv")

# %%
dataset.head()
dataset.loc[:,"PERID":"PERID"]
# Out:
#           PERID
# 0      25095143
# 1      13005143
# 2      67415143
# 3      70925143
# 4      75235143
# 5      47745143
# 6      33145143
# 7      63765143
# 8      57796143
# 9      66416143
# 10     51916143
# 11     40016143
# 12     99116143
# 13     85326143
# 14     63336143
# 15     64946143
# 16     73856143
# 17     82956143
# 18     65276143
# 19     58307143
# 20     67407143
# 21     83427143
# 22     68447143
# 23     65177143
# 24     77787143
# 25     96887143
# 26     46218143
# 27     15938143
# 28     15268143
# 29     79868143
# ...         ...
# 45688  14130679
# 45689  21950679
# 45690  65360679
# 45691  29960679
# 45692  22470679
# 45693  67970679
# 45694  95501679
# 45695  30001679
# 45696  64411679
# 45697  34221679
# 45698  11331679
# 45699  19671679
# 45700  37681679
# 45701  49002679
# 45702  67632679
# 45703  15352679
# 45704  71752679
# 45705  86062679
# 45706  17772679
# 45707  29382679
# 45708  99193679
# 45709  23313679
# 45710  90423679
# 45711  88143679
# 45712  75253679
# 45713  29663679
# 45714  43073679
# 45715  52173679
# 45716  29283679
# 45717  87483679
#
# [45718 rows x 1 columns]

# %%
dataset.shape
# Out:
# (45718, 72)

# %%
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(dataset, test_size=0.2)

# %%
train.shape
# Out:
# (36574, 72)

# %%
test.shape
# Out:
# (9144, 72)

# %%
dataset.groupby('Criminal').size()
# Out:
# Criminal
# 0    42543
# 1     3175
# dtype: int64

# %%
train.groupby('Criminal').size()
# Out:
# Criminal
# 0    34035
# 1     2539
# dtype: int64

# %%
test.groupby('Criminal').size()
# Out:
# Criminal
# 0    8508
# 1     636
# dtype: int64

# %%
x_train = train.loc[:,"IFATHER":"VEREP"]

# %%
x_train.head()
# Out:
#        IFATHER  NRCH17_2  IRHHSIZ2  IIHHSIZ2  IRKI17_2  IIKI17_2  IRHH65_2  \
# 16023        1         0         6         1         4         1         1
# 35653        4         2         5         1         3         1         2
# 45022        4         3         5         1         4         1         1
# 38873        4         0         4         1         1         1         1
# 5516         2         0         5         1         3         1         1
#
#        IIHH65_2  PRXRETRY  PRXYDATA  ...    POVERTY3  TOOLONG  TROUBUND  \
# 16023         1        99         1  ...           1        2         2
# 35653         1        99        99  ...           2        2         2
# 45022         1        99        99  ...           3        2         2
# 38873         1        99        99  ...           1        2         2
# 5516          1        99         1  ...           2        2         2
#
#        PDEN10  COUTYP2  MAIIN102  AIIND102     ANALWT_C  VESTR  VEREP
# 16023       2        2         2         2  3644.299292  40011      1
# 35653       2        2         2         2  1254.378780  40003      1
# 45022       2        2         2         2  5173.729966  40014      1
# 38873       1        1         2         2  1570.005036  40015      1
# 5516        2        1         2         2   260.889346  40041      2
#
# [5 rows x 70 columns]

# %%
y_train = train.loc[:,"Criminal":]

# %%
y_train.head()
# Out:
#        Criminal
# 16023         0
# 35653         0
# 45022         0
# 38873         0
# 5516          0

# %%
x_test = test.loc[:,"IFATHER":"VEREP"]

# %%
x_test.head()
# Out:
#        IFATHER  NRCH17_2  IRHHSIZ2  IIHHSIZ2  IRKI17_2  IIKI17_2  IRHH65_2  \
# 2489         2         0         6         1         4         1         1
# 9665         4         0         2         1         1         1         1
# 41012        1         0         6         1         4         1         1
# 29296        4         1         3         1         2         1         1
# 30517        4         0         2         1         1         1         1
#
#        IIHH65_2  PRXRETRY  PRXYDATA  ...    POVERTY3  TOOLONG  TROUBUND  \
# 2489          3        99         1  ...           1        2         2
# 9665          1        99         1  ...           3        2         2
# 41012         1        99         1  ...           2        2         2
# 29296         1        99        99  ...           3        2         2
# 30517         1        99        99  ...           2        2         2
#
#        PDEN10  COUTYP2  MAIIN102  AIIND102     ANALWT_C  VESTR  VEREP
# 2489        2        3         2         2   992.397402  40004      1
# 9665        2        3         2         2  3860.603782  40001      2
# 41012       1        2         2         2  1100.076532  40003      2
# 29296       1        1         2         2  6392.427665  40001      1
# 30517       1        1         2         2  4458.548714  40035      2
#
# [5 rows x 70 columns]

# %%
y_test = test.loc[:,"Criminal":]

# %%
y_test.head()
# Out:
#        Criminal
# 2489          0
# 9665          0
# 41012         0
# 29296         0
# 30517         0

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
svm1 = svm.SVC()

# %%
svm1.fit(x_train,y_train.values.ravel())

# %%
pred = svm1.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy = accuracy_score(y_test, pred)

# %%
print(accuracy)

# %%
print(pred)
# Out:
# [0 0 0 ..., 0 0 0]
